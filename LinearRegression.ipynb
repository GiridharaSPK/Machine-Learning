# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#load data from text file
data = np.loadtxt("ex1data1.txt",delimiter=",")
data = np.array(data)
print(data)
# Out:
# [[ 6.1101  17.592  ]
#  [ 5.5277   9.1302 ]
#  [ 8.5186  13.662  ]
#  [ 7.0032  11.854  ]
#  [ 5.8598   6.8233 ]
#  [ 8.3829  11.886  ]
#  [ 7.4764   4.3483 ]
#  [ 8.5781  12.     ]
#  [ 6.4862   6.5987 ]
#  [ 5.0546   3.8166 ]
#  [ 5.7107   3.2522 ]
#  [14.164   15.505  ]
#  [ 5.734    3.1551 ]
#  [ 8.4084   7.2258 ]
#  [ 5.6407   0.71618]
#  [ 5.3794   3.5129 ]
#  [ 6.3654   5.3048 ]
#  [ 5.1301   0.56077]
#  [ 6.4296   3.6518 ]
#  [ 7.0708   5.3893 ]
#  [ 6.1891   3.1386 ]
#  [20.27    21.767  ]
#  [ 5.4901   4.263  ]
#  [ 6.3261   5.1875 ]
#  [ 5.5649   3.0825 ]
#  [18.945   22.638  ]
#  [12.828   13.501  ]
#  [10.957    7.0467 ]
#  [13.176   14.692  ]
#  [22.203   24.147  ]
#  [ 5.2524  -1.22   ]
#  [ 6.5894   5.9966 ]
#  [ 9.2482  12.134  ]
#  [ 5.8918   1.8495 ]
#  [ 8.2111   6.5426 ]
#  [ 7.9334   4.5623 ]
#  [ 8.0959   4.1164 ]
#  [ 5.6063   3.3928 ]
#  [12.836   10.117  ]
#  [ 6.3534   5.4974 ]
#  [ 5.4069   0.55657]
#  [ 6.8825   3.9115 ]
#  [11.708    5.3854 ]
# ...

# %%
#seperate the input (X) and output (Y)
X = data[::,:1]
Y = data[::,1:]

# %%
plt.scatter(X.transpose(),Y.transpose(),40,color="blue",marker="+")
plt.xlabel("population in 10000's")
plt.ylabel("profit in 10000 $")
plt.title("SCATTER PLOT - 1")
plt.show()

# %%
df=pd.read_csv("AirQualityUCI.csv", delimiter = ';')

df.head(10)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
# 5  10/03/2004  23.00.00    1,2       1197.0      38.0      4,7          750.0
# 6  11/03/2004  00.00.00    1,2       1185.0      31.0      3,6          690.0
# 7  11/03/2004  01.00.00      1       1136.0      31.0      3,3          672.0
# 8  11/03/2004  02.00.00    0,9       1094.0      24.0      2,3          609.0
# 9  11/03/2004  03.00.00    0,6       1010.0      19.0      1,7          561.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# ...

# %%
X=df['NMHC(GT)']
Y=df['PT08.S3(NOx)']

# plotting the points 
plt.scatter(X,Y,2,color="red",marker="*")
 
# naming the x axis
plt.xlabel('NO2(GT)')
# naming the y axis
plt.ylabel('T')
 
# giving a title to my graph
plt.title('SCATTER PLOT 2')
 
# function to show the plot
plt.show()

# %%
dataset = pd.read_csv("day.csv")
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
x = dataset.temp
y = dataset.hum

b1 = np.cov(x,y,ddof=0)[0,1]/np.var(x)
b0 = (np.mean(y)-b1*np.mean(x))/2

plt.scatter(x,y,20,color="green",marker="^")
plt.title('SCATTER PLOT 3')
#plt.plot(x,eval('b0 + b1*x'))
plt.show()
